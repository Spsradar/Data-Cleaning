# %% [markdown]
# <a href="https://colab.research.google.com/github/Spsradar/Data-Cleaning/blob/main/Data_Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("new_file.csv")

# %%
# len(df.index)
# df.shape[1]
df.fillna(value=0)
# Out:
#       project_id  project_old_id  ... score_walk_work is_foreclosed
# 0              0             0.0  ...             0.0             f
# 1   project_8093             0.0  ...             0.0             f
# 2              0             0.0  ...             0.0             f
# 3   project_2729             0.0  ...             0.0             f
# 4              0             0.0  ...             0.0             f
# ..           ...             ...  ...             ...           ...
# 95             0             0.0  ...             0.0             f
# 96             0             0.0  ...             0.0             f
# 97  project_9225          9225.0  ...           100.0             f
# 98             0             0.0  ...             0.0             f
# 99             0             0.0  ...             0.0             f
#
# [100 rows x 233 columns]

# %%
df = df.drop(['geom', 'day'], axis=1)
df
# df.dropna(subset=['geom'], axis=0)
# Out:
#       project_id  project_old_id  ... score_walk_work is_foreclosed
# 0            NaN             NaN  ...             NaN             f
# 1   project_8093             NaN  ...             NaN             f
# 2            NaN             NaN  ...             NaN             f
# 3   project_2729             NaN  ...             NaN             f
# 4            NaN             NaN  ...             NaN             f
# ..           ...             ...  ...             ...           ...
# 95           NaN             NaN  ...             NaN             f
# 96           NaN             NaN  ...             NaN             f
# 97  project_9225          9225.0  ...           100.0             f
# 98           NaN             NaN  ...             NaN             f
# 99           NaN             NaN  ...             NaN             f
#
# [100 rows x 233 columns]

# %%
df.dropna(subset=['project_id'], axis=0)
# Out:
#                   project_id  project_old_id  ... score_walk_work is_foreclosed
# 1               project_8093             NaN  ...             NaN             f
# 3               project_2729             NaN  ...             NaN             f
# 9              project_11880             NaN  ...             NaN             f
# 10              project_5156             NaN  ...             NaN             f
# 11             project_11880             NaN  ...             NaN             f
# 12             project_14359             NaN  ...             NaN             f
# 16              project_1114             NaN  ...             NaN             f
# 17              project_2685             NaN  ...             NaN             f
# 18              project_2667             NaN  ...             NaN             f
# 19             project_14359             NaN  ...             NaN             f
# 20              project_2418             NaN  ...             NaN             f
# ...
